# %% [markdown]
# # 02 - Train and Evaluate ML Models
#
# This notebook trains and evaluates the Random Forest and Neural Network models
# for link stability prediction.
#
# It reuses the functions defined in `ml/train_model.py` and `ml/data_utils.py`.
#
# Make sure the dataset at `dataset/link_dataset.csv` exists before running.

# %%
import sys
import os
sys.path.insert(0, os.path.abspath('..'))

# %%
from ml import train_model
from ml.data_utils import DATA_PATH
os.chdir('..')
print("Using dataset:", DATA_PATH)
train_model.main()
# Out:
# Using dataset: dataset/link_dataset.csv
# Dataset path: dataset/link_dataset.csv
# Dataset size: (121275, 5)
#
# Random Forest Accuracy: 1.0
# Neural Network Accuracy: 0.9817357245928674
#
# Classification Report (Random Forest)
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7339
#            1       1.00      1.00      1.00     16916
#
#     accuracy                           1.00     24255
#    macro avg       1.00      1.00      1.00     24255
# weighted avg       1.00      1.00      1.00     24255
#
#
# Artifacts saved:
#   Random Forest model: results/random_forest_model.pkl
#   Random Forest metrics: results/metrics_random_forest.json
#   Neural Network model: results/neural_network_model.pkl
#   Neural Network metrics: results/metrics_neural_network.json
