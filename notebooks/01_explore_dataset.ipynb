# %% [markdown]
# # 01 - Explore MANET Link Dataset
#
# This notebook explores the generated MANET link dataset stored at `dataset/link_dataset.csv`.
#
# - Load the raw CSV
# - Show basic statistics and class balance
# - Visualize distance and link-stability distributions using the plotting helpers

# %%
import sys
import os
sys.path.insert(0, os.path.abspath('..'))

# %%
from ml.data_utils import load_raw_dataset
from ml import plot_results
os.chdir('..')
df = load_raw_dataset()
df.head()
# Out:
#    nodeA  nodeB  distance  time  link_status
# 0      0      1   18.6401     1            1
# 1      0      2   40.2639     1            1
# 2      0      3   60.6103     1            1
# 3      0      4   80.4021     1            1
# 4      0      5   98.7392     1            1

# %%
print("Dataset shape:", df.shape)
print("\nClass balance (link_status):")
print(df["link_status"].value_counts(normalize=True))
# Out:
# Dataset shape: (121275, 5)
#
# Class balance (link_status):
# link_status
# 1    0.69443
# 0    0.30557
# Name: proportion, dtype: float64

# %%
_ = plot_results.plot_distance_distribution(df)
_ = plot_results.plot_link_status(df)
